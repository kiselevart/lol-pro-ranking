# %%
import pandas as pd

# %%
df = pd.read_csv('OEFULL.csv')
# Out:
# /var/folders/0h/ch124vqs7dj_96gjw7qq3ksh0000gn/T/ipykernel_77372/2708909022.py:1: DtypeWarning: Columns (3,6,22,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('OEFULL.csv')

# %%
df
# Out:
#          index            gameid datacompleteness  \
# 0       862222          TRLH3/33         complete
# 1       862214          TRLH3/33         complete
# 2       862212          TRLH3/33         complete
# 3       862213          TRLH3/33         complete
# 4       862216          TRLH3/33         complete
# ...        ...               ...              ...
# 872023  292715  LOLTMNT02_181861         complete
# 872024  292706  LOLTMNT02_181861         complete
# 872025  292711  LOLTMNT02_181861         complete
# 872026  292712  LOLTMNT02_181861         complete
# 872027  292704  LOLTMNT02_181861         complete
#
#                                                       url  league  year  \
# 0       http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2014
# 1       http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2014
# 2       http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2014
# ...

# %%
df = df.dropna()
axis=1
thresh=int(0.9*len(df))
df = df.dropna(axis=0, thresh=int(0.9*len(df.columns)))

# %%
df
# Out:
# Empty DataFrame
# ...
