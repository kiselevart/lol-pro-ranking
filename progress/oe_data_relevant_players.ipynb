# %%
import pandas as pd

# %%
df = pd.read_csv('oe_clean.csv')
df
# Out:
#                   gameid  league  playoffs  game  participantid  side  \
# 0               TRLH3/33  EU LCS         0   1.0              3  Blue
# 1               TRLH3/33  EU LCS         0   1.0              1  Blue
# 2               TRLH3/33  EU LCS         0   1.0              2  Blue
# 3               TRLH3/33  EU LCS         0   1.0              5  Blue
# 4               TRLH3/33  EU LCS         0   1.0              6   Red
# ...                  ...     ...       ...   ...            ...   ...
# 665025  LOLTMNT02_181861      HW         0   5.0             10   Red
# 665026  LOLTMNT02_181861      HW         0   5.0              3  Blue
# 665027  LOLTMNT02_181861      HW         0   5.0              8   Red
# 665028  LOLTMNT02_181861      HW         0   5.0              9   Red
# 665029  LOLTMNT02_181861      HW         0   5.0              1  Blue
#
#        position  playername  gamelength  result  ...  wardsplaced  \
# ...

# %%
ranks = pd.read_csv('ranks.csv')
ranks
# Out:
#     playername  rank
# 0        Faker     1
# 1       Knight     2
# 2        Chovy     3
# 3       Peanut     4
# 4        Keria     5
# ..         ...   ...
# 465    KiWiKiD   466
# 466      Keane   467
# 467     Hakuho   468
# 468   Elementz   469
# 469       Care   470
#
# [470 rows x 2 columns]

# %%
df = df[df['playername'].isin(ranks['playername'])]
df.reset_index(drop=True, inplace=True)
df
# Out:
#                   gameid  league  playoffs  game  participantid  side  \
# 0               TRLH3/33  EU LCS         0   1.0              3  Blue
# 1               TRLH3/33  EU LCS         0   1.0              2  Blue
# 2               TRLH3/33  EU LCS         0   1.0              5  Blue
# 3               TRLH3/33  EU LCS         0   1.0              6   Red
# 4               TRLH3/33  EU LCS         0   1.0              4  Blue
# ...                  ...     ...       ...   ...            ...   ...
# 112289  LOLTMNT03_161676     LAS         0   2.0             10   Red
# 112290  LOLTMNT03_162490     LAS         0   2.0             10   Red
# 112291  LOLTMNT03_162500     LAS         0   1.0             10   Red
# 112292  LOLTMNT03_161683     LAS         0   2.0             10   Red
# 112293  LOLTMNT03_162503     LAS         0   2.0              5  Blue
#
#        position  playername  gamelength  result  ...  wardsplaced  \
# ...

# %%
df.to_csv('oe_relevant.csv', index=False)
